# %% [markdown]
# # predciting quality of wine

# %%
#importing the required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('winequality.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 9               7.5             0.500         0.36            6.10      0.071
# 10              6.7             0.580         0.08            1.80      0.097
# ...

# %% [markdown]
# ### cleaning the dataset

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# good                    0
# color                   0
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
df.count()
# Out:
# fixed acidity           6497
# volatile acidity        6497
# citric acid             6497
# residual sugar          6497
# chlorides               6497
# free sulfur dioxide     6497
# total sulfur dioxide    6497
# density                 6497
# pH                      6497
# sulphates               6497
# alcohol                 6497
# quality                 6497
# good                    6497
# color                   6497
# dtype: int64

# %%
df.shape
# Out:
# (6497, 14)

# %%
df1=df.head(10)
df1
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# good                      int64
# color                    object
# dtype: object

# %% [markdown]
# # Visualise the  distributions of various features and correlations between them

# %% [markdown]
# ## Univariant Data

# %%
sns.boxplot(df1['pH'])

# %%
sns.distplot(df1['pH'])

# %%
a =  np.power(df1['pH'],(1/2))
sns.kdeplot(a, shade=True, c='b')
# Out:
# C:\Users\ayush\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\matplotlib\cbook.py:2641: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
sns.boxplot(df1['alcohol'])

# %%
sns.distplot(df1['alcohol'])

# %%
a =  np.power(df1['alcohol'],(1/3))
sns.kdeplot(a, shade=True, c='b')
# Out:
# C:\Users\ayush\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\matplotlib\cbook.py:2641: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
a1 = np.log(df1['alcohol'])

# %%
##The graph is now lesser skewed and bit more like normally distributed graph.
a1 =  np.power(df1['alcohol'],(a1))
sns.kdeplot(a1, shade=True, c='b')
# Out:
# C:\Users\ayush\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\matplotlib\cbook.py:2641: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
sns.countplot(x='pH',data =df1)

# %%
sns.countplot(x='alcohol',data =df1)

# %%
sns.countplot(x='residual sugar',data =df1)

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.scatter(df1['pH'],df1['quality'],c='r', marker = "^")

# %%
plt.scatter(df1['alcohol'],df1['quality'],c='r', marker = "^")

# %%
plt.scatter(df1['residual sugar'],df1['quality'],c='r', marker = "^")

# %%
sns.jointplot(df1['pH'],df1['quality'], kind ='kde',color='g')

# %%
sns.jointplot(df1['alcohol'],df1['quality'], kind ='kde',color='g')

# %%
sns.jointplot(df1['residual sugar'],df1['quality'], kind ='kde',color='g')

# %%
sns.lmplot(x="pH",y="quality", data=df1, hue='good')

# %%
sns.lmplot(x="alcohol",y="quality", data=df1, hue='good')

# %%
sns.lmplot(x="alcohol",y="quality", data=df1, hue='good')

# %%
sns.barplot(x='alcohol',y='quality',data =df1)

# %%
sns.barplot(x='pH',y='quality',data =df1)

# %% [markdown]
# ## Multivariate Data

# %%
plt.figure(figsize=(10,8))
corr = df1.corr()
sns.heatmap(corr)

# %%
df1
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ## Feature engineering  to extract the correct features for the model

# %%
df2 = df1.iloc[:,8:9]
df2
# Out:
#      pH
# 0  3.51
# 1  3.20
# 2  3.26
# 3  3.16
# 4  3.51
# 5  3.51
# 6  3.30
# 7  3.39
# 8  3.36
# 9  3.35

# %%
df3 = df1.iloc[:,11:12]
df3
# Out:
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5
# 5        5
# 6        5
# 7        7
# 8        7
# 9        5

# %% [markdown]
# # Building a model to predict the wine quality index

# %%
x= np.array(df2)
y = np.array(df3)
x.shape
y.shape
# Out:
# (10, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.25,random_state = 0)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (7, 1) (7, 1)
# (3, 1) (3, 1)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LogisticRegr = LogisticRegression()
LogisticRegr.fit(X_train , Y_train)
# Out:
# C:\Users\ayush\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions = LogisticRegr.predict(X_test)

# %%
score =  LogisticRegr.score(Y_test,predictions)
print(score)
# Out:
# 1.0

# %% [markdown]
# # Naive Bayes

# %%
x1= np.array(df2)
y1 = np.array(df3)
x1.shape
y1.shape
# Out:
# (10, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.25,random_state = 0)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (7, 1) (7, 1)
# (3, 1) (3, 1)

# %%
from sklearn.naive_bayes import GaussianNB
#clf = GaussianNB()
#clf.fit(X_train, Y_train)
model = GaussianNB()

# %%
model.fit(X_train,Y_train.reshape(7,))
# Out:
# GaussianNB(priors=None)

# %%
anuman = model.predict(X_test)
anuman
# Out:
# array([5, 5, 5], dtype=int64)

# %%
from sklearn import metrics
metrics.accuracy_score(Y_test,anuman)
# Out:
# 0.66666666666666663

# %% [markdown]
# # SVM

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.30,random_state = 7)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (7, 1) (7, 1)
# (3, 1) (3, 1)

# %%
from sklearn.svm import SVC
from sklearn import datasets
from sklearn import metrics

# %% [markdown]
# # SVM(kernel= poly)

# %%
model_s = SVC( kernel = 'poly')

# %%
model_s.fit(X_train,Y_train.reshape(7,))
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
pred_1 = model_s.predict(X_test)

# %%
metrics.accuracy_score(Y_test,pred_1)
# Out:
# 0.66666666666666663

# %%
df4 =df1.drop(columns=['color'],axis=0)
df4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-80a44401ccd6> in <module>()
# ----> 1 df4 =df1.drop(columns=['color'],axis=0)
#       2 df4
#
# TypeError: drop() got an unexpected keyword argument 'columns'

# %%
x2= np.array(df4)
y2 = np.array(df3)
x2.shape
y2.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-00222a79d734> in <module>()
# ----> 1 x2= np.array(df4)
#       2 y2 = np.array(df3)
#       3 x2.shape
#       4 y2.shape
#
# NameError: name 'df4' is not defined

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.30,random_state = 7)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (7, 1) (7, 1)
# (3, 1) (3, 1)

# %%
from sklearn.svm import SVC
from sklearn import datasets
from sklearn import metrics

# %%
model1= SVC()

# %%
model1.fit(X_train,Y_train.reshape(7,))
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
pred_2 = model1.predict(X_test)

# %%
metrics.accuracy_score(Y_test,pred_2)
# Out:
# 0.66666666666666663

# %%
model1_a= SVC( kernel = 'poly',cache_size=200,C=0.9,random_state=7)

# %%
model1_a.fit(X_train,Y_train.reshape(7,))
# Out:
# SVC(C=0.9, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=7, shrinking=True,
#   tol=0.001, verbose=False)

# %%
pred_3 = model1_a.predict(X_test)

# %%
metrics.accuracy_score(Y_test,pred_3)
# Out:
# 0.66666666666666663

# %% [markdown]
# # Decision Tree

# %%
x2= np.array(df4)
y2 = np.array(df3)
x2.shape
y2.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-00222a79d734> in <module>()
# ----> 1 x2= np.array(df4)
#       2 y2 = np.array(df3)
#       3 x2.shape
#       4 y2.shape
#
# NameError: name 'df4' is not defined

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.25,random_state = 7)
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (7, 1) (7, 1)
# (3, 1) (3, 1)

# %%
from sklearn.tree import DecisionTreeClassifier
model10 = DecisionTreeClassifier(max_leaf_nodes=60, max_depth=10)
model10.fit(X_train , Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=60,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
score =  model10.score(X_test,Y_test)
print(score)
# Out:
# 0.666666666667

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
model4 = RandomForestClassifier()
model4.fit(X_train , Y_train.reshape(7,))
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
score =  model4.score(X_test,Y_test)
print(score)
# Out:
# 0.666666666667

# %% [markdown]
# # Ensemble Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score

# %%
estimators = []
model= LogisticRegression()
estimators.append(('logisic',LogisticRegr))
model1= DecisionTreeClassifier()
estimators.append(('DecisionTreeClassifier',model10))
model2= SVC()
estimators.append(('SVC',model1_a))
ensemble = VotingClassifier(estimators)

# %%
ensemble.fit(X_train , Y_train.reshape(7,))
# Out:
# VotingClassifier(estimators=[('logisic', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)), ('Decisio...ly',
#   max_iter=-1, probability=False, random_state=7, shrinking=True,
#   tol=0.001, verbose=False))],
#          flatten_transform=None, n_jobs=1, voting='hard', weights=None)

# %%
from sklearn.metrics import accuracy_score
pred5 = ensemble.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(Y_test, pred5))
# Out:
#              precision    recall  f1-score   support
#
#           5       0.67      1.00      0.80         2
#           7       0.00      0.00      0.00         1
#
# avg / total       0.44      0.67      0.53         3
# C:\Users\ayush\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
